# %%
import requests
from bs4 import BeautifulSoup
url=input("")
try:
    response=requests.get(url)
except:
    print("error fetching page")
html=response.text
soup=BeautifulSoup(html,'html.parser')
# Title
if soup.title:
    print("TITLE:")
    print(soup.title.get_text().strip())
# Body
print("\nBODY:")
if soup.body:
    print(soup.body.get_text(separator=' ',strip=True))
# Links
print("\nLINKS:")
for a in soup.find_all('a'):
    link=a.get('href')
    if link:
        print(link)
# Out:
# https://bardx.in/
# TITLE:
# Nirmal's Digital Space
#
# BODY:
# Nirmal's Digital Space Home About Me Gallery Blog Complexity Analyzer JEE Chatbot Contact Toggle navigation menu Crafting a special welcome for you... Hey, I'm Nirmal Kumar A B-Tech Computer Science student at SRMU Lucknow, exploring the vast world of technology, with a keen interest in star gazing and photography. I know you have been waiting for so long for this website. There have been some unexpected delays, in consolidating the ‘content’ and actually making the website. This is not the actual one but the content will be similar, except organized in a much better format with better aesthetics. About Me Learn more about my background and interests. Explore My Gallery A collection of moments I've captured. Explore Blog Updates My thoughts on CS, stars, and photos. Explore JEE Chatbot Get AI guidance for your JEE preparation. Explore Complexity Analyzer Analyze the time complexity of code snippets. Explore Get In Touch Ways to connect with me. Explore © 2025 Nirmal Kumar. All rights reserved.
#
# LINKS:
# /
# /
# /about
# /gallery
# /blog
# /complexity-analyzer
# /chatbot
# /contact
# /about
# /gallery
# /blog
# /chatbot
# /complexity-analyzer
# /contact
# https://twitter.com/_ibardx
# https://instagram.com/_bardx?igsh=YzljYTk1ODg3Zg==
# https://www.linkedin.com/in/bardx/
# https://github.com/NIRMAL20062
